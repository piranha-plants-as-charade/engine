# %%
import os

try:
    if CONFIGURED_DIRS:  # type: ignore
        pass
except:
    PLAYGROUND_DIR = os.getcwd()
    os.chdir("../src")

CONFIGURED_DIRS = True

print(f"Playground directory: {PLAYGROUND_DIR}")  # type: ignore
print(f"Working directory: {os.getcwd()}")
# Out:
# Playground directory: /Users/maxhuang/Documents/school/cs489/piranha-plants-as-charade/playground
# Working directory: /Users/maxhuang/Documents/school/cs489/piranha-plants-as-charade/src

# %%
import numpy as np
import scipy.io.wavfile as wav  # type: ignore
from IPython.display import Audio
from typing import List

from common.voice_sample_library import VoiceSampleLibrary, VoiceSampleLibraryConfig
from common.structures.pitch import Pitch

# %%
sample_lib = VoiceSampleLibrary(
    VoiceSampleLibraryConfig(
        src="piranha_plant_voice_samples",
    ),
)
samples = (
    sample_lib.get_sample("A", Pitch.from_str("C3")),
    sample_lib.get_sample("E", Pitch.from_str("G3")),
    sample_lib.get_sample("I", Pitch.from_str("D4")),
    sample_lib.get_sample("O", Pitch.from_str("A4")),
    sample_lib.get_sample("U", Pitch.from_str("E5")),
    sample_lib.get_sample("A", Pitch.from_str("B5")),
    sample_lib.get_sample("E", Pitch.from_str("F#6")),
)
empty_sample = np.zeros(len(samples[0]) // 2, dtype=np.float32)

output: List[np.float32] = []
for i, sample in enumerate(samples):
    output.extend(sample)
    output.extend(empty_sample)
# Out:
# Loaded I.wav.
# Loaded O.wav.
# Loaded A.wav.
# Loaded U.wav.
# Loaded E.wav.

# %%
OUTPUT_DIR = os.path.join(PLAYGROUND_DIR, "output")
OUTPUT_WAV_SRC = os.path.join(OUTPUT_DIR, "voice_sample_fifths.wav")

os.makedirs(OUTPUT_DIR, exist_ok=True)

wav.write(  # type: ignore
    OUTPUT_WAV_SRC,
    sample_lib.sample_rate,
    np.array(output),
)

# %%
Audio(OUTPUT_WAV_SRC)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
